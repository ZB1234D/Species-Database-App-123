# %%
import pandas as pd
import numpy as np
file="species data.xlsx"
x= pd.read_excel(file)
print("Rows and Columns are :",x.shape)
x.head()
# Out:
# Rows and Columns are : (22, 12)
#    Sr No      Scientific name  \
# 0    1.0  Aleurites moluccana
# 1    2.0      Tectona grandis
# 2    3.0        Toona ciliata
# 3    4.0    Sterculia foetida
# 4    5.0      Albizia lebbeck
#
#                                            Etymology  Common name  \
# 0  Aleurites is from Greek aleuron meaning “flour...      Ai-Kami
# 1  Tectona comes from Greek téktōn “carpenter/bui...      Ai-Teka
# 2  Toona is from the Indian vernacular name “toon...     Ai-Saria
# 3  Sterculia derives from Latin Sterculius, the R...     Ai-nitas
# 4  Albizia honors Filippo degli Albizzi, who intr...  Ai-Samatuku
#
#                                              Habitat Unnamed: 5  \
# 0  Common from coast to mid-hills in Timor-Leste,...        NaN
# 1  Mostly planted and sometimes naturalised on dr...        NaN
# 2  it grows along moist streams and ravines on we...        NaN
# 3  A lowland tree of hot, dry coastal plains and ...        NaN
# 4  The species grows along hilly roadsides at low...        NaN
#
#                                            Phenology  \
# 0                                Throughout the Year
# 1  Flowering: June to September; Fruiting: Novemb...
# 2    Flowering: March - May; Fruiting: July - August
# 3  Flowering: February to March, Fruiting: Januar...
# 4  Flowering: September–November; Fruiting: May–July
#
#                            Identification Characters  \
# 0  A medium–large tree; leaves alternate, large, ...
# 1  A large, deciduous tree; leaves very large, op...
# 2  A tall, deciduous tree;  trunk often buttresse...
# 3  A large, straight, deciduous tree; bark smooth...
# 4  A medium–large, deciduous tree; bark grey, fis...
#
#                      Leaf type Fruit Type  \
# 0                       Simple      Drupe
# 1                       Simple      Drupe
# 2  Pinnately compound (single)    Capsule
# 3           Palmately compound   Follicle
# 4  Pinnately compound (double)        Pod
#
#                                     Seed Germination  \
# 0  Collect brown mature fruits from the tree or d...
# 1  Collect mature, dry fruits; remove the outer s...
# 2  Collect ripe, fully mature fruits from the tre...
# 3  Collect mature red fruit and split the fruit t...
# 4  Collect pods when they’re dry, light brown, an...
#
#                                                 Pest
# 0  For candlenut, the most immediate nursery thre...
# 1  Termites are the main stem problem in teak; th...
# 2  Young toon (Toona ciliata) often suffers from ...
# 3  In nurseries of Sterculia foetida, the main pr...
# 4  In nurseries, Albizia seedlings often die from...

# %%
# Remove the unnamed column and it values
x = x.loc[:, ~x.columns.str.startswith("Unnamed")]
print("After:", x.shape)
print(x.columns)
x = x.dropna(how="all")
x
# Out:
# After: (22, 11)
# Index(['Sr No', 'Scientific name', 'Etymology', 'Common name', 'Habitat',
#        'Phenology', 'Identification Characters', 'Leaf type', 'Fruit Type',
#        'Seed Germination', 'Pest'],
#       dtype='object')
#     Sr No          Scientific name  \
# 0     1.0      Aleurites moluccana
# 1     2.0          Tectona grandis
# 2     3.0            Toona ciliata
# 3     4.0        Sterculia foetida
# 4     5.0          Albizia lebbeck
# 5     6.0       Azadirachta indica
# 7     7.0           Acacia mangium
# 8     8.0       Alstonia scholaris
# 9     9.0   Calophyllum inophyllum
# 10   10.0       Falcataria falcata
# 11   11.0         Canarium vulgare
# 12   12.0  Casuarina equisetifolia
# 13   13.0      Pterocarpus indicus
# 14   14.0            Delonix regia
# 15   15.0        Tamarindus indica
# 16   16.0     Eucalyptus urophylla
# 17   17.0          Eucalyptus alba
# 18   18.0          Parkia speciosa
# 19   19.0       Terminalia catappa
# 20   20.0  Peltophorum pterocarpum
# 21   21.0           Santalum album
#
#                                             Etymology  \
# 0   Aleurites is from Greek aleuron meaning “flour...
# 1   Tectona comes from Greek téktōn “carpenter/bui...
# 2   Toona is from the Indian vernacular name “toon...
# 3   Sterculia derives from Latin Sterculius, the R...
# 4   Albizia honors Filippo degli Albizzi, who intr...
# 5   Azadirachta is from Persian azad-darakht meani...
# 7   Acacia is from Greek akis (“point/barb”), refe...
# 8   Alstonia commemorates botanist Charles Alston,...
# 9   Calophyllum is from Greek kalos (“beautiful”) ...
# 10  Falcataria refers to “falcate” (sickle-shaped)...
# 11  Canarium is from the Malay/Moluccan vernacular...
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
#
#                            Common name  \
# 0                              Ai-Kami
# 1                              Ai-Teka
# 2                             Ai-Saria
# 3                             Ai-nitas
# 4                          Ai-Samatuku
# 5                         Sumaer Malae
# 7                               Akasia
# 8                        Ai‑hanek/Rito
# 9                          Too/Samplon
# 10                     Ai‑bahe/Ai-Kafe
# 11                             Ai-Kiar
# 12                            Ai-Kakeu
# 13                               Ai-na
# 14  Ai‑kesi/Madre‑Kakau/Samatuku Malae
# 15                           Ai‑sukaer
# 16                               Ai‑ru
# 17                            Ai‑bubur
# 18               Petai‑cina/Pete/Petai
# 19          Ai‑Kalesi/Ketapang/Ai‑lese
# 20                   Ai‑silose/Ai‑mame
# 21                           Ai‑kameli
#
#                                               Habitat  \
# 0   Common from coast to mid-hills in Timor-Leste,...
# 1   Mostly planted and sometimes naturalised on dr...
# 2   it grows along moist streams and ravines on we...
# 3   A lowland tree of hot, dry coastal plains and ...
# 4   The species grows along hilly roadsides at low...
# 5   The species grows on barren lands and is commo...
# 7   The species grows best on degraded lands and i...
# 8   The species occurs naturally across Timor-Lest...
# 9   Calophyllum inophyllum grows abundantly along ...
# 10  Falcataria falcata grows best in the cooler hi...
# 11  Canarium vulgare grows occasionally along hill...
# 12  Casuarina equisetifolia grows abundantly acros...
# 13  Pterocarpus indicus grows along hilly roadside...
# 14  Delonix regia is commonly planted along roadsi...
# 15  Tamarindus indica is common and abundant, espe...
# 16  Eucalyptus urophylla is occasionally found in ...
# 17  Eucalyptus alba grows abundantly on low-altitu...
# 18  Parkia speciosa is not common and is mainly fo...
# 19  Terminalia catappa commonly grows in coastal a...
# 20  Peltophorum pterocarpum grows along hilly road...
# 21  In Timor-Leste, Santalum album grows naturally...
#
#                                             Phenology  \
# 0                                 Throughout the Year
# 1   Flowering: June to September; Fruiting: Novemb...
# 2     Flowering: March - May; Fruiting: July - August
# 3   Flowering: February to March, Fruiting: Januar...
# 4   Flowering: September–November; Fruiting: May–July
# 5      Flowering: January–March; Fruiting: May–August
# 7   Flowering: July to August; Fruting: December t...
# 8              Flowering:May-June; Fruting: June-July
# 9         Flowering: April-May; Fruiting: June-August
# 10  Flowering: March to June & October to December...
# 11  Flowering: September to December; Fruting: May...
# 12  Flowering: September to October; Fruting: Febr...
# 13  Flowering: August to September; Fruting-May to...
# 14                                                NaN
# 15                           Flowering: June to July;
# 16  Flowering: December to January; Fruting: April...
# 17  Flowering: December to January; Fruting: April...
# 18  Flowering: May to June; Fruting: August to Sep...
# 19     Flowering: May to June; Fruting: April to June
# 20    Flowering: April to May; Fruting: April to June
# 21      Flowering: Nov to Dec; Fruting: March to June
#
#                             Identification Characters  \
# 0   A medium–large tree; leaves alternate, large, ...
# 1   A large, deciduous tree; leaves very large, op...
# 2   A tall, deciduous tree;  trunk often buttresse...
# 3   A large, straight, deciduous tree; bark smooth...
# 4   A medium–large, deciduous tree; bark grey, fis...
# 5   Azadirachta indica is a medium to large evergr...
# 7   A medium–large fast-growing tree with a broad ...
# 8   A very tall tree with a thick trunk, when cut ...
# 9                                                 NaN
# 10  Falcataria falcata is a very fast-growing medi...
# 11  \nA tall tree up to about 45 m with butteresse...
# 12  A medium–large tree often 10–30 m tall;  Leave...
# 13  An evergreen to semi-deciduous medium–large tr...
# 14  A deciduous to semi-evergreen medium-sized tre...
# 15  A long-lived evergreen to semi-deciduous mediu...
# 16  A tall evergreen tree that can grow about 45–5...
# 17  A small to medium tree usually about 5–18 m ta...
# 18  A medium–large tree about 15–40 m tall, with y...
# 19  A large deciduous to semi-evergreen tree, with...
# 20  A fast-growing evergreen to semi-deciduous med...
# 21  A small to medium evergreen tree, usually with...
#
#                       Leaf type Fruit Type  \
# 0                        Simple      Drupe
# 1                        Simple      Drupe
# 2   Pinnately compound (single)    Capsule
# 3            Palmately compound   Follicle
# 4   Pinnately compound (double)        Pod
# 5   Pinnately compound (triple)      Drupe
# 7                        Simple        Pod
# 8                           NaN        NaN
# 9                           NaN        NaN
# 10                          NaN        NaN
# 11                          NaN        NaN
# 12                          NaN        NaN
# 13                          NaN        NaN
# 14                          NaN        NaN
# 15                          NaN        NaN
# 16                          NaN        NaN
# 17                          NaN        NaN
# 18                          NaN        NaN
# 19                          NaN        NaN
# 20                          NaN        NaN
# 21                          NaN        NaN
#
#                                      Seed Germination  \
# 0   Collect brown mature fruits from the tree or d...
# 1   Collect mature, dry fruits; remove the outer s...
# 2   Collect ripe, fully mature fruits from the tre...
# 3   Collect mature red fruit and split the fruit t...
# 4   Collect pods when they’re dry, light brown, an...
# 5   Neem fruits are collected when they turn yello...
# 7   Acacia mangium pods are collected when fully d...
# 8   Alstonia scholaris fruits are long, slender pa...
# 9   Calophyllum inophyllum fruits are round drupes...
# 10  Falcataria falcata produces thin, flat pods in...
# 11  Canarium vulgare  produces smooth, ovoid drupe...
# 12  Casuarina equisetifolia produces small, woody ...
# 13  Pterocarpus indicus produces distinctive round...
# 14  Delonix regia produces long, woody pods (30–60...
# 15  Tamarindus indica produces elongated, brittle ...
# 16  Eucalyptus urphylls produce small, capsule-bor...
# 17  Eucalyptus alba produces very small, dust-like...
# 18  Parkia speciosa (petai/stink bean) seeds come ...
# 19  Terminalia catappa produces ovoid drupes that ...
# 20  Peltophorum pterocarpum produces flat, woody p...
# 21  Sandalwood produces small, hard seeds enclosed...
#
#                                                  Pest
# 0   For candlenut, the most immediate nursery thre...
# 1   Termites are the main stem problem in teak; th...
# 2   Young toon (Toona ciliata) often suffers from ...
# 3   In nurseries of Sterculia foetida, the main pr...
# 4   In nurseries, Albizia seedlings often die from...
# 5   Neem trees are usually resistant, but some pes...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN

# %%
df = x.copy()

for col in df.columns:
    if df[col].dtype == "object":
        df[col] = df[col].astype(str).str.strip()
        df[col] = df[col].replace(["", "nan", "NaN", "None"], np.nan)

df.dropna(how="all", inplace=True)
df.drop_duplicates(inplace=True)

print("\nAfter cleaning the new shape:", df.shape)

print("\nMissing values based on columns:")
print(df.isna().sum())

if "scientific_name" in df.columns:
    dup = df["scientific_name"].duplicated().sum()
    print(f"\nDuplicate scientific_name values: {dup}")

print("\nUnique values:")
for col in ["Scientific name", "Common name", "Habitat", "Leaf type", "Fruit Type"]:
    if col in df.columns:
        print(f"{col} → {df[col].nunique()} unique values")

df.to_excel("species_en_cleaned.xlsx", index=False)
print("\nSaved the file as species_en_cleaned.xlsx")
# Out:
# After cleaning the new shape: (21, 11)
#
# Missing values based on columns:
# Sr No                         0
# Scientific name               0
# Etymology                    10
# Common name                   0
# Habitat                       0
# Phenology                     1
# Identification Characters     1
# Leaf type                    14
# Fruit Type                   14
# Seed Germination              0
# Pest                         15
# dtype: int64
#
# Unique values:
# Scientific name → 21 unique values
# Common name → 21 unique values
# Habitat → 21 unique values
# Leaf type → 5 unique values
# Fruit Type → 4 unique values
#
# Saved the file as species_en_cleaned.xlsx

# %%
if "Scientific name" in x.columns:
    dup_sci = x["Scientific name"].duplicated(keep=False)
    num_dup_sci = dup_sci.sum()
    print(f"\n Number of duplicated Scientific name values: {num_dup_sci}")
    if num_dup_sci > 0:
        print(x.loc[dup_sci, ["Scientific name"]].sort_values("Scientific name").head(20))

critical_cols = ["Scientific name", "Common name", "Habitat", "Leaf type"]

for col in critical_cols:
    if col in x.columns:
        num_missing = x[col].isna().sum()
        print(f" {col}: {num_missing} missing values")
# Out:
#  Number of duplicated Scientific name values: 0
#  Scientific name: 0 missing values
#  Common name: 0 missing values
#  Habitat: 0 missing values
#  Leaf type: 14 missing values

# %%
text_long = ["Identification Characters", "Phenology", "Etymology"]

for col in text_long:
    if col in x.columns:
        lengths = x[col].dropna().astype(str).str.len()
        print(f"\ntext length statistics for {col}:")
        print("  Mean is :", lengths.mean())
        print("  Min is :", lengths.min())
        print("  Max is :", lengths.max())
# Out:
# text length statistics for Identification Characters:
#   Mean is : 557.65
#   Min is : 307
#   Max is : 818
#
# text length statistics for Phenology:
#   Mean is : 53.55
#   Min is : 19
#   Max is : 133
#
# text length statistics for Etymology:
#   Mean is : 146.1818181818182
#   Min is : 116
#   Max is : 172

# %%
import matplotlib.pyplot as plt

if "Leaf type" in x.columns:
    leaf_counts = x["Leaf type"].value_counts().sort_values(ascending=False)

    plt.figure()
    leaf_counts.plot(kind="bar")
    plt.title("Count of Species in each Leaf Type")
    plt.xlabel("Leaf Type")
    plt.ylabel("Count of Species")
    plt.xticks(rotation=50, ha="right")
    plt.tight_layout()
    plt.show()
    
else:
    print("Column 'Leaf type' not found.")

# %%
if "Fruit Type" in x.columns:
    fruit_counts = x["Fruit Type"].value_counts().sort_values(ascending=False)

    plt.figure()
    fruit_counts.plot(kind="bar")
    plt.title("Count of Species in each Fruit Type")
    plt.xlabel("Fruit Type")
    plt.ylabel("Count of Species")
    plt.xticks(rotation=50, ha="right")
    plt.tight_layout()
    plt.show()
else:
    print("Column 'Fruit Type' not found.")

# %%
import pandas as pd
import uuid

df = pd.read_excel("species_en_cleaned.xlsx")
df.insert(0, "id", [str(uuid.uuid4()) for _ in range(len(df))])
df.to_excel("species_en.xlsx", index=False)
print("ID added and file saved successfully.")
# Out:
# ID added and file saved successfully.

# %%
print("Rows and Columns are :",df.shape)
# Out:
# Rows and Columns are : (21, 13)
